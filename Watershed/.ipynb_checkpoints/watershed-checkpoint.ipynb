# %%
                                                     #  FOR SINGLE IMAGE
import cv2
import numpy as np
import os

def segment_cell(image_path):
    # Read the image
    image = cv2.imread(image_path)
    
    # Convert the image to grayscale
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    
    # Perform adaptive thresholding to obtain a binary image
    _, threshold = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)
    
    # Perform morphological operations to remove noise and fill gaps
    kernel = np.ones((3, 3), np.uint8)
    opening = cv2.morphologyEx(threshold, cv2.MORPH_OPEN, kernel, iterations=2)
    
    # Find the sure background region
    sure_bg = cv2.dilate(opening, kernel, iterations=3)
    
    # Find the sure foreground region
    dist_transform = cv2.distanceTransform(opening, cv2.DIST_L2, 5)
    _, sure_fg = cv2.threshold(dist_transform, 0.7 * dist_transform.max(), 255, 0)
    
    # Find the unknown region
    sure_fg = np.uint8(sure_fg)
    unknown = cv2.subtract(sure_bg, sure_fg)
    
    # Create a marker image
    _, markers = cv2.connectedComponents(sure_fg)
    markers = markers + 1
    markers[unknown == 255] = 0
    
    # Apply the watershed algorithm
    markers = cv2.watershed(image, markers)
    
    # Color the segmented cells
    image[markers == -1] = [0, 0, 255]  # Mark boundaries with red color
    
    return image

# Provide the path to the input image (without the extension)
image_path = "Herlev Dataset/img"

# Ensure the path includes the proper extension
image_path_with_extension = image_path + ".png"

# Perform image segmentation
segmented_image = segment_cell(image_path_with_extension)

# Save the segmented image as BMP
output_path = "segmented_image.png"
cv2.imwrite(output_path, segmented_image)
print("Segmented image saved successfully as png.")
# Out:
# Segmented image saved successfully as png.

# %%
                                                # FOR MULTIPLE IMAGES (1)carcinoma_situ
import cv2
import numpy as np
import os

def segment_cell(image_path):
    # Read the image
    image = cv2.imread(image_path)
    
    # Convert the image to grayscale
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    
    # Perform adaptive thresholding to obtain a binary image
    _, threshold = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)
    
    # Perform morphological operations to remove noise and fill gaps
    kernel = np.ones((3, 3), np.uint8)
    opening = cv2.morphologyEx(threshold, cv2.MORPH_OPEN, kernel, iterations=2)
    
    # Find the sure background region
    sure_bg = cv2.dilate(opening, kernel, iterations=3)
    
    # Find the sure foreground region
    dist_transform = cv2.distanceTransform(opening, cv2.DIST_L2, 5)
    _, sure_fg = cv2.threshold(dist_transform, 0.7 * dist_transform.max(), 255, 0)
    
    # Find the unknown region
    sure_fg = np.uint8(sure_fg)
    unknown = cv2.subtract(sure_bg, sure_fg)
    
    # Create a marker image
    _, markers = cv2.connectedComponents(sure_fg)
    markers = markers + 1
    markers[unknown == 255] = 0
    
    # Apply the watershed algorithm
    markers = cv2.watershed(image, markers)
    
    # Color the segmented cells
    image[markers == -1] = [0, 0, 255]  # Mark boundaries with red color
    
    return image

# Provide the path to the folder containing the input images
folder_path = 'carcinoma_in_situ'

# Get a list of all image files in the folder
image_files = [f for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))]

# Process each image in the folder
for image_file in image_files:
    # Construct the full path to the image
    image_path = os.path.join(folder_path, image_file)
    
    # Perform image segmentation
    segmented_image = segment_cell(image_path)
    
    # Save the segmented image with the same filename and BMP extension
    output_path = os.path.splitext(image_path)[0] + ".png"
    cv2.imwrite(output_path, segmented_image)
    
    print(f"Segmented image saved successfully as png: {output_path}")
# Out:
# Segmented image saved successfully as png: carcinoma_in_situ\149315671-149315740-001_filtered_0.png
# Segmented image saved successfully as png: carcinoma_in_situ\149315671-149315740-001_filtered_1.png
# Segmented image saved successfully as png: carcinoma_in_situ\149315671-149315740-001_filtered_2.png
# Segmented image saved successfully as png: carcinoma_in_situ\149315671-149315740-001_filtered_3.png
# Segmented image saved successfully as png: carcinoma_in_situ\149
png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_5973.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_5985.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_5995.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_6123.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_613.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_6141.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_6215.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_6281.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_6340.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_6370.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_6463.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_6565.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_6623.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_6671.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_6690.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_6724.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_673.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_6735.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_6761.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_6830.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_6858.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_6877.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_6905.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_6906.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_6910.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_6925.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_6963.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_7027.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_7030.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_713.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_7170.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_7177.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_7207.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_7209.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_7236.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_7273.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_7279.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_7289.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_7296.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_7298.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_7347.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_7361.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_7396.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_7404.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_7491.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_7547.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_7571.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_7580.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_7581.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_7611.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_7641.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_7645.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_7650.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_7675.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_7702.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_7779.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_7781.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_7836.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_7857.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_7871.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_7874.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_7882.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_7883.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_794.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_8018.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_8054.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_8113.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_8146.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_8161.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_8273.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_8284.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_829.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_8325.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_8380.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_8427.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_8450.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_8491.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_8499.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_8519.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_8625.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_8702.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_8730.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_8759.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_8810.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_8819.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_8827.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_8830.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_8836.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_8854.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_8893.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_8898.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_8972.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_8983.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_9096.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_9118.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_9120.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_9162.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_9174.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_92.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_9207.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_9214.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_925.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_930.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_9317.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_9347.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_937.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_9383.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_9412.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_9440.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_9474.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_9478.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_95.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_9556.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_9617.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_9655.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_9760.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_9793.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_9795.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_9845.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_9932.png
# Segmented image saved successfully as png: carcinoma_in_situ\augmented_0_9977.png

# %%
                                    # FOR MULTIPLE IMAGES (2)light_dysplastic_filtered_nlm_aug
import cv2
import numpy as np
import os

def segment_cell(image_path):
    # Read the image
    image = cv2.imread(image_path)
    
    # Convert the image to grayscale
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    
    # Perform adaptive thresholding to obtain a binary image
    _, threshold = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)
    
    # Perform morphological operations to remove noise and fill gaps
    kernel = np.ones((3, 3), np.uint8)
    opening = cv2.morphologyEx(threshold, cv2.MORPH_OPEN, kernel, iterations=2)
    
    # Find the sure background region
    sure_bg = cv2.dilate(opening, kernel, iterations=3)
    
    # Find the sure foreground region
    dist_transform = cv2.distanceTransform(opening, cv2.DIST_L2, 5)
    _, sure_fg = cv2.threshold(dist_transform, 0.7 * dist_transform.max(), 255, 0)
    
    # Find the unknown region
    sure_fg = np.uint8(sure_fg)
    unknown = cv2.subtract(sure_bg, sure_fg)
    
    # Create a marker image
    _, markers = cv2.connectedComponents(sure_fg)
    markers = markers + 1
    markers[unknown == 255] = 0
    
    # Apply the watershed algorithm
    markers = cv2.watershed(image, markers)
    
    # Color the segmented cells
    image[markers == -1] = [0, 0, 255]  # Mark boundaries with red color
    
    return image

# Provide the path to the folder containing the input images
folder_path = 'light_dysplastic_filtered_nlm_aug'

# Get a list of all image files in the folder
image_files = [f for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))]

# Process each image in the folder
for image_file in image_files:
    # Construct the full path to the image
    image_path = os.path.join(folder_path, image_file)
    
    # Perform image segmentation
    segmented_image = segment_cell(image_path)
    
    # Save the segmented image with the same filename and BMP extension
    output_path = os.path.splitext(image_path)[0] + ".png"
    cv2.imwrite(output_path, segmented_image)
    
    print(f"Segmented image saved successfully as png: {output_path}")
# Out:
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\153314466-153314473-003_filtered_0.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\153314466-153314473-003_filtered_1.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\153314466-153314473-003_filtered_2.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\153314466-153314473-003_filtered_3.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\153314466-153314473-003_filtered_4.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\153314759-153314767-002_filtered_0.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\153314759-153314767-002_filtered_1.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\153314759-153314767-002_filtered_2.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\153314759-153314767-002_filtered_3.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\153314759-153314767-002_filtered_4.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\153314759-153314767-003_filtered_0.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\153314759-153314767-003_filtered_1.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\153314759-153314767-003_filtered_2.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\153314759-153314767-003_filtered_3.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\153314759-153314767-003_filtered_4.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\153314857-153314882-001_filtered_0.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\
png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_5335.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_534.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_5344.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_5370.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_5375.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_5407.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_5409.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_5439.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_5440.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_5507.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_5546.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_555.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_5554.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_562.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_5632.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_5658.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_5660.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_5677.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_5682.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_5707.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_5719.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_5727.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_583.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_585.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_5855.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_5961.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_5988.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_599.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_6012.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_6069.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_6138.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_6208.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_6267.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_632.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_6335.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_6362.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_6448.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_6501.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_6502.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_6503.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_6527.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_6552.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_6562.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_6563.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_6593.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_6597.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_6599.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_660.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_6608.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_6626.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_664.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_6702.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_6725.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_6738.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_676.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_6800.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_6833.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_6851.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_6884.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_6912.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_6937.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_7017.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_7056.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_7144.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_7180.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_7255.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_7342.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_7349.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_7431.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_7458.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_7532.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_7567.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_7575.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_7676.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_7692.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_771.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_7745.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_7798.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_7861.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_787.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_7881.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_7883.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_7903.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_7905.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_7959.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_8048.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_8141.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_8150.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_818.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_8197.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_8200.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_8229.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_8250.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_8280.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_829.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_8297.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_8345.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_8357.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_843.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_8472.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_85.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_8516.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_8538.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_8539.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_8618.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_8644.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_866.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_8672.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_8674.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_8683.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_876.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_8764.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_8774.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_8781.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_8876.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_8898.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_8903.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_8915.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_8977.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_8980.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_8998.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_9052.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_9061.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_9075.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_9077.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_9085.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_9140.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_9159.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_927.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_9273.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_9279.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_928.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_9312.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_9328.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_9385.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_939.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_9396.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_9482.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_9538.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_9555.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_9566.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_9575.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_9578.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_9604.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_9614.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_9644.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_9677.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_9694.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_970.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_9716.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_975.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_9767.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_9769.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_9785.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_9856.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_9879.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_9954.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_9967.png
# Segmented image saved successfully as png: light_dysplastic_filtered_nlm_aug\augmented_0_9972.png

# %%
                                    # FOR MULTIPLE IMAGES (3)moderate_dysplastic_filtered_nlm
import cv2
import numpy as np
import os

def segment_cell(image_path):
    # Read the image
    image = cv2.imread(image_path)
    
    # Convert the image to grayscale
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    
    # Perform adaptive thresholding to obtain a binary image
    _, threshold = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)
    
    # Perform morphological operations to remove noise and fill gaps
    kernel = np.ones((3, 3), np.uint8)
    opening = cv2.morphologyEx(threshold, cv2.MORPH_OPEN, kernel, iterations=2)
    
    # Find the sure background region
    sure_bg = cv2.dilate(opening, kernel, iterations=3)
    
    # Find the sure foreground region
    dist_transform = cv2.distanceTransform(opening, cv2.DIST_L2, 5)
    _, sure_fg = cv2.threshold(dist_transform, 0.7 * dist_transform.max(), 255, 0)
    
    # Find the unknown region
    sure_fg = np.uint8(sure_fg)
    unknown = cv2.subtract(sure_bg, sure_fg)
    
    # Create a marker image
    _, markers = cv2.connectedComponents(sure_fg)
    markers = markers + 1
    markers[unknown == 255] = 0
    
    # Apply the watershed algorithm
    markers = cv2.watershed(image, markers)
    
    # Color the segmented cells
    image[markers == -1] = [0, 0, 255]  # Mark boundaries with red color
    
    return image

# Provide the path to the folder containing the input images
folder_path = 'moderate_dysplastic_filtered_nlm_aug'

# Get a list of all image files in the folder
image_files = [f for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))]

# Process each image in the folder
for image_file in image_files:
    # Construct the full path to the image
    image_path = os.path.join(folder_path, image_file)
    
    # Perform image segmentation
    segmented_image = segment_cell(image_path)
    
    # Save the segmented image with the same filename and BMP extension
    output_path = os.path.splitext(image_path)[0] + ".png"
    cv2.imwrite(output_path, segmented_image)
    
    print(f"Segmented image saved successfully as png: {output_path}")
# Out:
# Segmented image saved successfully as png: moderate_dysplastic_filtered_nlm_aug\149316754-149316779-001_filtered_0.png
# Segmented image saved successfully as png: moderate_dysplastic_filtered_nlm_aug\
png
# Segmented image saved successfully as png: moderate_dysplastic_filtered_nlm_aug\augmented_0_8219.png
# Segmented image saved successfully as png: moderate_dysplastic_filtered_nlm_aug\augmented_0_8222.png
# Segmented image saved successfully as png: moderate_dysplastic_filtered_nlm_aug\augmented_0_8235.png
# Segmented image saved successfully as png: moderate_dysplastic_filtered_nlm_aug\augmented_0_8316.png
# Segmented image saved successfully as png: moderate_dysplastic_filtered_nlm_aug\augmented_0_8318.png
# Segmented image saved successfully as png: moderate_dysplastic_filtered_nlm_aug\augmented_0_8326.png
# Segmented image saved successfully as png: moderate_dysplastic_filtered_nlm_aug\augmented_0_8356.png
# Segmented image saved successfully as png: moderate_dysplastic_filtered_nlm_aug\augmented_0_8391.png
# Segmented image saved successfully as png: moderate_dysplastic_filtered_nlm_aug\augmented_0_8493.png
# Segmented image saved successfully as png: moderate_dysplastic_filtered_nlm_aug\augmented_0_8499.png
# Segmented image saved successfully as png: moderate_dysplastic_filtered_nlm_aug\augmented_0_8526.png
# Segmented image saved successfully as png: moderate_dysplastic_filtered_nlm_aug\augmented_0_8539.png
# Segmented image saved successfully as png: moderate_dysplastic_filtered_nlm_aug\augmented_0_8540.png
# Segmented image saved successfully as png: moderate_dysplastic_filtered_nlm_aug\augmented_0_8603.png
# Segmented image saved successfully as png: moderate_dysplastic_filtered_nlm_aug\augmented_0_8604.png
# Segmented image saved successfully as png: moderate_dysplastic_filtered_nlm_aug\augmented_0_8636.png
# Segmented image saved successfully as png: moderate_dysplastic_filtered_nlm_aug\augmented_0_8639.png
# Segmented image saved successfully as png: moderate_dysplastic_filtered_nlm_aug\augmented_0_8642.png
# Segmented image saved successfully as png: moderate_dysplastic_filtered_nlm_aug\augmented_0_8654.png
# Segmented image saved successfully as png: moderate_dysplastic_filtered_nlm_aug\augmented_0_8685.png
# Segmented image saved successfully as png: moderate_dysplastic_filtered_nlm_aug\augmented_0_8689.png
# Segmented image saved successfully as png: moderate_dysplastic_filtered_nlm_aug\augmented_0_8774.png
# Segmented image saved successfully as png: moderate_dysplastic_filtered_nlm_aug\augmented_0_8786.png
# Segmented image saved successfully as png: moderate_dysplastic_filtered_nlm_aug\augmented_0_8823.png
# Segmented image saved successfully as png: moderate_dysplastic_filtered_nlm_aug\augmented_0_8858.png
# Segmented image saved successfully as png: moderate_dysplastic_filtered_nlm_aug\augmented_0_8946.png
# Segmented image saved successfully as png: moderate_dysplastic_filtered_nlm_aug\augmented_0_9029.png
# Segmented image saved successfully as png: moderate_dysplastic_filtered_nlm_aug\augmented_0_9030.png
# Segmented image saved successfully as png: moderate_dysplastic_filtered_nlm_aug\augmented_0_9052.png
# Segmented image saved successfully as png: moderate_dysplastic_filtered_nlm_aug\augmented_0_9131.png
# Segmented image saved successfully as png: moderate_dysplastic_filtered_nlm_aug\augmented_0_9133.png
# Segmented image saved successfully as png: moderate_dysplastic_filtered_nlm_aug\augmented_0_9137.png
# Segmented image saved successfully as png: moderate_dysplastic_filtered_nlm_aug\augmented_0_9163.png
# Segmented image saved successfully as png: moderate_dysplastic_filtered_nlm_aug\augmented_0_924.png
# Segmented image saved successfully as png: moderate_dysplastic_filtered_nlm_aug\augmented_0_9244.png
# Segmented image saved successfully as png: moderate_dysplastic_filtered_nlm_aug\augmented_0_9270.png
# Segmented image saved successfully as png: moderate_dysplastic_filtered_nlm_aug\augmented_0_9273.png
# Segmented image saved successfully as png: moderate_dysplastic_filtered_nlm_aug\augmented_0_9285.png
# Segmented image saved successfully as png: moderate_dysplastic_filtered_nlm_aug\augmented_0_930.png
# Segmented image saved successfully as png: moderate_dysplastic_filtered_nlm_aug\augmented_0_9302.png
# Segmented image saved successfully as png: moderate_dysplastic_filtered_nlm_aug\augmented_0_9419.png
# Segmented image saved successfully as png: moderate_dysplastic_filtered_nlm_aug\augmented_0_9422.png
# Segmented image saved successfully as png: moderate_dysplastic_filtered_nlm_aug\augmented_0_9451.png
# Segmented image saved successfully as png: moderate_dysplastic_filtered_nlm_aug\augmented_0_9471.png
# Segmented image saved successfully as png: moderate_dysplastic_filtered_nlm_aug\augmented_0_9478.png
# Segmented image saved successfully as png: moderate_dysplastic_filtered_nlm_aug\augmented_0_9479.png
# Segmented image saved successfully as png: moderate_dysplastic_filtered_nlm_aug\augmented_0_9509.png
# Segmented image saved successfully as png: moderate_dysplastic_filtered_nlm_aug\augmented_0_9558.png
# Segmented image saved successfully as png: moderate_dysplastic_filtered_nlm_aug\augmented_0_9560.png
# Segmented image saved successfully as png: moderate_dysplastic_filtered_nlm_aug\augmented_0_9575.png
# Segmented image saved successfully as png: moderate_dysplastic_filtered_nlm_aug\augmented_0_9589.png
# Segmented image saved successfully as png: moderate_dysplastic_filtered_nlm_aug\augmented_0_9611.png
# Segmented image saved successfully as png: moderate_dysplastic_filtered_nlm_aug\augmented_0_9627.png
# Segmented image saved successfully as png: moderate_dysplastic_filtered_nlm_aug\augmented_0_9674.png
# Segmented image saved successfully as png: moderate_dysplastic_filtered_nlm_aug\augmented_0_9699.png
# Segmented image saved successfully as png: moderate_dysplastic_filtered_nlm_aug\augmented_0_9713.png
# Segmented image saved successfully as png: moderate_dysplastic_filtered_nlm_aug\augmented_0_9792.png
# Segmented image saved successfully as png: moderate_dysplastic_filtered_nlm_aug\augmented_0_9817.png
# Segmented image saved successfully as png: moderate_dysplastic_filtered_nlm_aug\augmented_0_9821.png
# Segmented image saved successfully as png: moderate_dysplastic_filtered_nlm_aug\augmented_0_9865.png
# Segmented image saved successfully as png: moderate_dysplastic_filtered_nlm_aug\augmented_0_9900.png
# Segmented image saved successfully as png: moderate_dysplastic_filtered_nlm_aug\augmented_0_9932.png
# Segmented image saved successfully as png: moderate_dysplastic_filtered_nlm_aug\augmented_0_9947.png

# %%
                                    # FOR MULTIPLE IMAGES (4)normal_columnar_filtered_nlm_aug
import cv2
import numpy as np
import os

def segment_cell(image_path):
    # Read the image
    image = cv2.imread(image_path)
    
    # Convert the image to grayscale
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    
    # Perform adaptive thresholding to obtain a binary image
    _, threshold = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)
    
    # Perform morphological operations to remove noise and fill gaps
    kernel = np.ones((3, 3), np.uint8)
    opening = cv2.morphologyEx(threshold, cv2.MORPH_OPEN, kernel, iterations=2)
    
    # Find the sure background region
    sure_bg = cv2.dilate(opening, kernel, iterations=3)
    
    # Find the sure foreground region
    dist_transform = cv2.distanceTransform(opening, cv2.DIST_L2, 5)
    _, sure_fg = cv2.threshold(dist_transform, 0.7 * dist_transform.max(), 255, 0)
    
    # Find the unknown region
    sure_fg = np.uint8(sure_fg)
    unknown = cv2.subtract(sure_bg, sure_fg)
    
    # Create a marker image
    _, markers = cv2.connectedComponents(sure_fg)
    markers = markers + 1
    markers[unknown == 255] = 0
    
    # Apply the watershed algorithm
    markers = cv2.watershed(image, markers)
    
    # Color the segmented cells
    image[markers == -1] = [0, 0, 255]  # Mark boundaries with red color
    
    return image

# Provide the path to the folder containing the input images
folder_path = 'normal_columnar_filtered_nlm_aug'

# Get a list of all image files in the folder
image_files = [f for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))]

# Process each image in the folder
for image_file in image_files:
    # Construct the full path to the image
    image_path = os.path.join(folder_path, image_file)
    
    # Perform image segmentation
    segmented_image = segment_cell(image_path)
    
    # Save the segmented image with the same filename and BMP extension
    output_path = os.path.splitext(image_path)[0] + ".png"
    cv2.imwrite(output_path, segmented_image)
    
    print(f"Segmented image saved successfully as png: {output_path}")
# Out:
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\157185781-157185814-001_filtered_0.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\157185781-157185814-001_filtered_1.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\157185781-157185814-001_filtered_2.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\157185781-157185814-001_filtered_3.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\157185781-157185814-001_filtered_4.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\157185781-157185814-002_filtered_0.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\157185781-157185814-002_filtered_1.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\157185781-157185814-002_filtered_2.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\157185781-157185814-002_filtered_3.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\157185781-157185814-002_filtered_4.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\157224172-157224207-001_filtered_0.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\157224172-157224207-001_filtered_1.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\157224172-157224207-001_filtered_2.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\157224172-157224207-001_filtered_3.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\157224172-157224207-001_filtered_4.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\157224172-157224207-002_filtered_0.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\157224172-157224207-002_filtered_1.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\157224172-157224207-002_filtered_2.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\157224172-157224207-002_filtered_3.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\157224172-157224207-002_filtered_4.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\157224172-157224207-003_filtered_0.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\157224172-157224207-003_filtered_1.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\157224172-157224207-003_filtered_2.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\157224172-157224207-003_filtered_3.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\157224172-157224207-003_filtered_4.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\157227058-157227087-001_filtered_0.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\157227058-157227087-001_filtered_1.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\157227058-157227087-001_filtered_2.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\
png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\158986920-158986928-002_filtered_4.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\158986920-158986928-003_filtered_0.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\158986920-158986928-003_filtered_1.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\158986920-158986928-003_filtered_2.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\158986920-158986928-003_filtered_3.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\158986920-158986928-003_filtered_4.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\158986920-158986928-004_filtered_0.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\158986920-158986928-004_filtered_1.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\158986920-158986928-004_filtered_2.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\158986920-158986928-004_filtered_3.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\158986920-158986928-004_filtered_4.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\158986920-158986928-005_filtered_0.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\158986920-158986928-005_filtered_1.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\158986920-158986928-005_filtered_2.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\158986920-158986928-005_filtered_3.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\158986920-158986928-005_filtered_4.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\158986920-158986928-006_filtered_0.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\158986920-158986928-006_filtered_1.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\158986920-158986928-006_filtered_2.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\158986920-158986928-006_filtered_3.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\158986920-158986928-006_filtered_4.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_1091.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_1207.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_1238.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_1258.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_1338.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_1502.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_1539.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_1602.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_1643.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_1739.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_1810.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_1856.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_190.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_1997.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_2.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_2011.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_2013.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_2029.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_2097.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_2170.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_2219.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_2237.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_226.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_2328.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_2340.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_2352.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_237.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_2421.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_2423.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_2530.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_269.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_2713.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_2836.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_2890.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_2929.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_2948.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_2968.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_2992.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_3060.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_3067.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_3123.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_3132.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_3173.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_3215.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_3218.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_3376.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_341.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_3417.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_3420.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_347.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_3472.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_3518.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_3608.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_371.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_3745.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_3786.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_3794.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_3886.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_39.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_398.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_400.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_4133.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_414.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_4166.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_4186.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_4221.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_4251.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_4256.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_429.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_4301.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_4310.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_4347.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_4352.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_4360.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_4408.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_4535.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_4666.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_4748.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_4902.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_4935.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_5017.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_5058.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_5190.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_5216.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_5316.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_5385.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_5571.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_569.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_5716.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_5718.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_575.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_5755.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_5773.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_5842.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_5917.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_5952.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_5996.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_6004.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_6087.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_6112.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_6154.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_6231.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_6331.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_6366.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_6388.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_645.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_6523.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_6612.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_6639.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_6643.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_6680.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_6755.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_6924.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_6950.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_6955.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_7001.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_7018.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_7158.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_7239.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_7289.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_7372.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_7452.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_7508.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_7544.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_764.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_7650.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_7659.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_7711.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_7796.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_7848.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_8024.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_812.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_818.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_8262.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_8272.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_8296.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_8302.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_8315.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_8322.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_8420.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_8457.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_846.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_8590.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_8611.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_8708.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_8740.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_8746.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_8774.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_8820.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_8932.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_8976.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_8978.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_8994.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_9.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_900.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_9087.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_9130.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_9197.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_9222.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_9246.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_9355.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_9360.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_938.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_9537.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_9545.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_9555.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_9605.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_9672.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_9697.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_9735.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_9770.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_9775.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_9803.png
# Segmented image saved successfully as png: normal_columnar_filtered_nlm_aug\augmented_0_9870.png

# %%
                                    # FOR MULTIPLE IMAGES (5)normal_intermediate_filtered_nlm_aug
import cv2
import numpy as np
import os

def segment_cell(image_path):
    # Read the image
    image = cv2.imread(image_path)
    
    # Convert the image to grayscale
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    
    # Perform adaptive thresholding to obtain a binary image
    _, threshold = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)
    
    # Perform morphological operations to remove noise and fill gaps
    kernel = np.ones((3, 3), np.uint8)
    opening = cv2.morphologyEx(threshold, cv2.MORPH_OPEN, kernel, iterations=2)
    
    # Find the sure background region
    sure_bg = cv2.dilate(opening, kernel, iterations=3)
    
    # Find the sure foreground region
    dist_transform = cv2.distanceTransform(opening, cv2.DIST_L2, 5)
    _, sure_fg = cv2.threshold(dist_transform, 0.7 * dist_transform.max(), 255, 0)
    
    # Find the unknown region
    sure_fg = np.uint8(sure_fg)
    unknown = cv2.subtract(sure_bg, sure_fg)
    
    # Create a marker image
    _, markers = cv2.connectedComponents(sure_fg)
    markers = markers + 1
    markers[unknown == 255] = 0
    
    # Apply the watershed algorithm
    markers = cv2.watershed(image, markers)
    
    # Color the segmented cells
    image[markers == -1] = [0, 0, 255]  # Mark boundaries with red color
    
    return image

# Provide the path to the folder containing the input images
folder_path = 'normal_intermediate_filtered_nlm_aug'

# Get a list of all image files in the folder
image_files = [f for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))]

# Process each image in the folder
for image_file in image_files:
    # Construct the full path to the image
    image_path = os.path.join(folder_path, image_file)
    
    # Perform image segmentation
    segmented_image = segment_cell(image_path)
    
    # Save the segmented image with the same filename and BMP extension
    output_path = os.path.splitext(image_path)[0] + ".png"
    cv2.imwrite(output_path, segmented_image)
    
    print(f"Segmented image saved successfully as png: {output_path}")
# Out:
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209522940-209522970-001_filtered_0.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209522940-209522970-001_filtered_1.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209522940-209522970-001_filtered_2.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209522940-209522970-001_filtered_3.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209522940-209522970-001_filtered_4.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209522940-209522991-001_filtered_0.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209522940-209522991-001_filtered_1.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209522940-209522991-001_filtered_2.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209522940-209522991-001_filtered_3.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209522940-209522991-001_filtered_4.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209522940-209523052-001_filtered_0.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209522940-209523052-001_filtered_1.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209522940-209523052-001_filtered_2.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209522940-209523052-001_filtered_3.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209522940-209523052-001_filtered_4.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209565409-209565466-001_filtered_0.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209565409-209565466-001_filtered_1.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209565409-209565466-001_filtered_2.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209565409-209565466-001_filtered_3.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209565409-209565466-001_filtered_4.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209565409-209565503-001_filtered_0.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209565409-209565503-001_filtered_1.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209565409-209565503-001_filtered_2.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209565409-209565503-001_filtered_3.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209565409-209565503-001_filtered_4.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209565409-209565600-001_filtered_0.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209565409-209565600-001_filtered_1.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209565409-209565600-001_filtered_2.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209565409-209565600-001_filtered_3.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209565409-209565600-001_filtered_4.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209565698-209565729-001_filtered_0.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209565698-209565729-001_filtered_1.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209565698-209565729-001_filtered_2.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209565698-209565729-001_filtered_3.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209565698-209565729-001_filtered_4.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209565698-209565772-001_filtered_0.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209565698-209565772-001_filtered_1.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209565698-209565772-001_filtered_2.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209565698-209565772-001_filtered_3.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209565698-209565772-001_filtered_4.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209565864-209565890-001_filtered_0.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209565864-209565890-001_filtered_1.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209565864-209565890-001_filtered_2.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209565864-209565890-001_filtered_3.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209565864-209565890-001_filtered_4.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209565864-209565911-001_filtered_0.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209565864-209565911-001_filtered_1.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209565864-209565911-001_filtered_2.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209565864-209565911-001_filtered_3.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209565864-209565911-001_filtered_4.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209565864-209565950-001_filtered_0.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209565864-209565950-001_filtered_1.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209565864-209565950-001_filtered_2.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209565864-209565950-001_filtered_3.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209565864-209565950-001_filtered_4.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209566047-209566095-001_filtered_0.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209566047-209566095-001_filtered_1.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209566047-209566095-001_filtered_2.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209566047-209566095-001_filtered_3.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209566047-209566095-001_filtered_4.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209566047-209566125-001_filtered_0.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209566047-209566125-001_filtered_1.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209566047-209566125-001_filtered_2.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209566047-209566125-001_filtered_3.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209566047-209566125-001_filtered_4.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209566205-209566247-001_filtered_0.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209566205-209566247-001_filtered_1.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209566205-209566247-001_filtered_2.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209566205-209566247-001_filtered_3.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209566205-209566247-001_filtered_4.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209566205-209566266-001_filtered_0.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209566205-209566266-001_filtered_1.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209566205-209566266-001_filtered_2.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209566205-209566266-001_filtered_3.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209566205-209566266-001_filtered_4.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209566205-209566289-001_filtered_0.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209566205-209566289-001_filtered_1.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209566205-209566289-001_filtered_2.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209566205-209566289-001_filtered_3.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209566205-209566289-001_filtered_4.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209566205-209566321-001_filtered_0.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209566205-209566321-001_filtered_1.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209566205-209566321-001_filtered_2.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209566205-209566321-001_filtered_3.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209566205-209566321-001_filtered_4.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209566205-209566333-001_filtered_0.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209566205-209566333-001_filtered_1.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209566205-209566333-001_filtered_2.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209566205-209566333-001_filtered_3.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209566205-209566333-001_filtered_4.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209566399-209566464-001_filtered_0.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209566399-209566464-001_filtered_1.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209566399-209566464-001_filtered_2.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209566399-209566464-001_filtered_3.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209566399-209566464-001_filtered_4.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209566399-209566485-001_filtered_0.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209566399-209566485-001_filtered_1.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209566399-209566485-001_filtered_2.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209566399-209566485-001_filtered_3.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209566399-209566485-001_filtered_4.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209566399-209566517-001_filtered_0.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209566399-209566517-001_filtered_1.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209566399-209566517-001_filtered_2.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209566399-209566517-001_filtered_3.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\209566399-209566517-001_filtered_4.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_1127.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_113.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_1176.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_1260.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_127.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_1367.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_1481.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_1500.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_166.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_1717.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_1731.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_1732.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_1847.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_1954.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_2.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_2029.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_2031.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_2058.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_2189.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_2215.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_2229.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_2349.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_257.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_2591.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_2857.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_2878.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_3031.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_3081.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_3098.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_3165.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_321.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_3348.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_3354.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_3364.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_3382.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_3405.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_3556.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_3606.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_3637.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_3638.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_3759.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_3938.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_4034.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_4052.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_4061.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_4093.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_4165.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_4320.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_4324.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_4517.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_4538.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_4603.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_4798.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_4833.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_4857.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_4988.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_5121.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_5199.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_5354.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_5444.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_5454.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_5471.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_5582.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_5585.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_5587.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_5617.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_5836.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_6024.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_6053.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_6068.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_6112.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_6125.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_6185.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_6193.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_6317.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_6598.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_6648.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_6696.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_6883.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_6974.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_6979.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_7111.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_7138.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_7158.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_73.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_74.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_7439.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_7602.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_7604.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_7661.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_781.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_7826.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_7899.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_7928.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_7946.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_7971.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_8006.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_8151.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_821.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_8281.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_8331.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_8363.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_8369.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_8398.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_8412.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_8426.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_8504.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_8505.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_8564.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_8691.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_8718.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_8764.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_8767.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_8819.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_8822.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_8996.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_9036.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_9058.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_9114.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_9180.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_9230.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_9251.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_926.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_9509.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_9637.png
# Segmented image saved successfully as png: normal_intermediate_filtered_nlm_aug\augmented_0_9891.png

# %%
                                    # FOR MULTIPLE IMAGES (6)normal_superficiel_filtered_nlm_aug
import cv2
import numpy as np
import os

def segment_cell(image_path):
    # Read the image
    image = cv2.imread(image_path)
    
    # Convert the image to grayscale
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    
    # Perform adaptive thresholding to obtain a binary image
    _, threshold = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)
    
    # Perform morphological operations to remove noise and fill gaps
    kernel = np.ones((3, 3), np.uint8)
    opening = cv2.morphologyEx(threshold, cv2.MORPH_OPEN, kernel, iterations=2)
    
    # Find the sure background region
    sure_bg = cv2.dilate(opening, kernel, iterations=3)
    
    # Find the sure foreground region
    dist_transform = cv2.distanceTransform(opening, cv2.DIST_L2, 5)
    _, sure_fg = cv2.threshold(dist_transform, 0.7 * dist_transform.max(), 255, 0)
    
    # Find the unknown region
    sure_fg = np.uint8(sure_fg)
    unknown = cv2.subtract(sure_bg, sure_fg)
    
    # Create a marker image
    _, markers = cv2.connectedComponents(sure_fg)
    markers = markers + 1
    markers[unknown == 255] = 0
    
    # Apply the watershed algorithm
    markers = cv2.watershed(image, markers)
    
    # Color the segmented cells
    image[markers == -1] = [0, 0, 255]  # Mark boundaries with red color
    
    return image

# Provide the path to the folder containing the input images
folder_path = 'normal_superficiel_filtered_nlm_aug'

# Get a list of all image files in the folder
image_files = [f for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))]

# Process each image in the folder
for image_file in image_files:
    # Construct the full path to the image
    image_path = os.path.join(folder_path, image_file)
    
    # Perform image segmentation
    segmented_image = segment_cell(image_path)
    
    # Save the segmented image with the same filename and BMP extension
    output_path = os.path.splitext(image_path)[0] + ".png"
    cv2.imwrite(output_path, segmented_image)
    
    print(f"Segmented image saved successfully as png: {output_path}")
# Out:
# Segmented image saved successfully as png: normal_superficiel_filtered_nlm_aug\157181569-157181599-001_filtered_0.png
# Segmented image saved successfully as png: normal_superficiel_filtered_nlm_aug\157181569-157181599-001_filtered_1.png
# Segmented image saved successfully as png: normal_superficiel_filtered_nlm_aug\157181569-157181599-001_filtered_2.png
# Segmented image saved successfully as png: normal_superficiel_filtered_nlm_aug\157181569-157181599-001_filtered_3.png
# Segmented image saved successfully as png: normal_superficiel_filtered_nlm_aug\157181569-157181599-001_filtered_4.png
# Segmented image saved successfully as png: normal_superficiel_filtered_nlm_aug\157224412-157224429-001_filtered_0.png
# Segmented image saved successfully as png: normal_superficiel_filtered_nlm_aug\157224412-157224429-001_filtered_1.png
# Segmented image saved successfully as png: normal_superficiel_filtered_nlm_aug\157224412-157224429-001_filtered_2.png
# Segmented image saved successfully as png: normal_superficiel_filtered_nlm_aug\157224412-157224429-001_filtered_3.png
# Segmented image saved successfully as png: normal_superficiel_filtered_nlm_aug\157224412-157224429-001_filtered_4.png
# Segmented image saved successfully as png: normal_superficiel_filtered_nlm_aug\157224458-157224483-001_filtered_0.png
# Segmented image saved successfully as png: normal_superficiel_filtered_nlm_aug\157224458-157224483-001_filtered_1.png
# Segmented image saved successfully as png: normal_superficiel_filtered_nlm_aug\157224458-157224483-001_filtered_2.png
# Segmented image saved successfully as png: normal_superficiel_filtered_nlm_aug\157224458-157224483-001_filtered_3.png
# Segmented image saved successfully as png: normal_superficiel_filtered_nlm_aug\157224458-157224483-001_filtered_4.png
# Segmented image saved successfully as png: normal_superficiel_filtered_nlm_aug\157224504-157224520-001_filtered_0.png
# Segmented image saved successfully as png: normal_superficiel_filtered_nlm_aug\157224504-157224520-001_filtered_1.png
# Segmented image saved successfully as png: normal_superficiel_filtered_nlm_aug\157224504-157224520-001_filtered_2.png
# Segmented image saved successfully as png: normal_superficiel_filtered_nlm_aug\157224504-157224520-001_filtered_3.png
# Segmented image saved successfully as png: normal_superficiel_filtered_nlm_aug\157224504-157224520-001_filtered_4.png
# Segmented image saved successfully as png: normal_superficiel_filtered_nlm_aug\157267647-157267732-001_filtered_0.png
# Segmented image saved successfully as png: normal_superficiel_filtered_nlm_aug\157267647-157267732-001_filtered_1.png
# Segmented image saved successfully as png: normal_superficiel_filtered_nlm_aug\157267647-157267732-001_filtered_2.png
# Segmented image saved successfully as png: normal_superficiel_filtered_nlm_aug\157267647-157267732-001_filtered_3.png
# Segmented image saved successfully as png: normal_superficiel_filtered_nlm_aug\157267647-157267732-001_filtered_4.png
# Segmented image saved successfully as png: normal_superficiel_filtered_nlm_aug\157268242-157268296-001_filtered_0.png
# Segmented image saved successfully as png: normal_superficiel_filtered_nlm_aug\157268242-157268296-001_filtered_1.png
# Segmented image saved successfully as png: normal_superficiel_filtered_nlm_aug\157268242-157268296-001_filtered_2.png
# Segmented image saved successfully as png: normal_superficiel_filtered_nlm_aug\157268242-157268296-001_filtered_3.png
# Segmented image saved successfully as png: normal_superficiel_filtered_nlm_aug\157268242-157268296-001_filtered_4.png
# Segmented image saved successfully as png: normal_superficiel_filtered_nlm_aug\157268342-157268376-001_filtered_0.png
# Segmented image saved successfully as png: normal_superficiel_filtered_nlm_aug\157268342-157268376-001_filtered_1.png
# Segmented image saved successfully as png: normal_superficiel_filtered_nlm_aug\157268342-157268376-001_filtered_2.png
# Segmented image saved successfully as png: normal_superficiel_filtered_nlm_aug\157268342-157268376-001_filtered_3.png
# Segmented image saved successfully as png: normal_superficiel_filtered_nlm_aug\157268342-157268376-001_filtered_4.png
# Segmented image saved successfully as png: normal_superficiel_filtered_nlm_aug\157268342-157268401-001_filtered_0.png
# Segmented image saved successfully as png: normal_superficiel_filtered_nlm_aug\157268342-157268401-001_filtered_1.png
# Segmented image saved successfully as png: normal_superficiel_filtered_nlm_aug\157268342-157268401-001_filtered_2.png
# Segmented image saved successfully as png: normal_superficiel_filtered_nlm_aug\157268342-157268401-001_filtered_3.png
# Segmented image saved successfully as png: normal_superficiel_filtered_nlm_aug\157268342-157268401-001_filtered_4.png
# Segmented image saved successfully as png: normal_superficiel_filtered_nlm_aug\157268504-157268544-001_filtered_0.png
# Segmented image saved successfully as png: normal_superficiel_filtered_nlm_aug\157268504-157268544-001_filtered_1.png
# Segmented image saved successfully as png: normal_superficiel_filtered_nlm_aug\157268504-157268544-001_filtered_2.png
# Segmented image saved successfully as png: normal_superficiel_filtered_nlm_aug\157268504-157268544-001_filtered_3.png
# Segmented image saved successfully as png: normal_superficiel_filtered_nlm_aug\157268504-157268544-001_filtered_4.png
# Segmented image saved successfully as png: normal_superficiel_filtered_nlm_aug\157268587-157268617-001_filtered_0.png
# Segmented image saved successfully as png: normal_superficiel_filtered_nlm_aug\157268587-157268617-001_filtered_1.png
# Segmented image saved successfully as png: normal_superficiel_filtered_nlm_aug\157268587-157268617-001_filtered_2.png
# Segmented image saved successfully as png: normal_superficiel_filtered_nlm_aug\157268587-157268617-001_filtered_3.png
# Segmented image saved successfully as png: normal_superficiel_filtered_nlm_aug\157268587-157268617-001_filtered_4.png
# Segmented image saved successfully as png: normal_superficiel_filtered_nlm_aug\158987033-158987057-001_filtered_0.png
# Segmented image saved successfully as png: normal_superficiel_filtered_nlm_aug\158987033-158987057-001_filtered_1.png
# Segmented image saved successfully as png: normal_superficiel_filtered_nlm_aug\158987033-158987057-001_filtered_2.png
# Segmented image saved successfully as png: normal_superficiel_filtered_nlm_aug\158987033-158987057-001_filtered_3.png
# Segmented image saved successfully as png: normal_superficiel_filtered_nlm_aug\158987033-158987057-001_filtered_4.png
# Segmented image saved successfully as png: normal_superficiel_filtered_nlm_aug\158987453-158987462-001_filtered_0.png
# Segmented image saved successfully as png: normal_superficiel_filtered_nlm_aug\158987453-158987462-001_filtered_1.png
# Segmented image saved successfully as png: normal_superficiel_filtered_nlm_aug\158987453-158987462-001_filtered_2.png
# Segmented image saved successfully as png: normal_superficiel_filtered_nlm_aug\158987453-158987462-001_filtered_3.png
# Segmented image saved successfully as png: normal_superficiel_filtered_nlm_aug\158987453-158987462-001_filtered_4.png
# Segmented image saved successfully as png: normal_superficiel_filtered_nlm_aug\158987493-158987499-001_filtered_0.png
# Segmented image saved successfully as png: normal_superficiel_filtered_nlm_aug\158987493-158987499-001_filtered_1.png
# Segmented image saved successfully as png: normal_superficiel_filtered_nlm_aug\158987493-158987499-001_filtered_2.png
# Segmented image saved successfully as png: normal_superficiel_filtered_nlm_aug\158987493-158987499-001_filtered_3.png
# Segmented image saved successfully as png: normal_superficiel_filtered_nlm_aug
png
# Segmented image saved successfully as png: normal_superficiel_filtered_nlm_aug\augmented_0_9964.png
# Segmented image saved successfully as png: normal_superficiel_filtered_nlm_aug\augmented_0_9995.png

# %%
                                    # FOR MULTIPLE IMAGES (7)severe_dysplastic_filtered_nlm_aug
import cv2
import numpy as np
import os

def segment_cell(image_path):
    # Read the image
    image = cv2.imread(image_path)
    
    # Convert the image to grayscale
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    
    # Perform adaptive thresholding to obtain a binary image
    _, threshold = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)
    
    # Perform morphological operations to remove noise and fill gaps
    kernel = np.ones((3, 3), np.uint8)
    opening = cv2.morphologyEx(threshold, cv2.MORPH_OPEN, kernel, iterations=2)
    
    # Find the sure background region
    sure_bg = cv2.dilate(opening, kernel, iterations=3)
    
    # Find the sure foreground region
    dist_transform = cv2.distanceTransform(opening, cv2.DIST_L2, 5)
    _, sure_fg = cv2.threshold(dist_transform, 0.7 * dist_transform.max(), 255, 0)
    
    # Find the unknown region
    sure_fg = np.uint8(sure_fg)
    unknown = cv2.subtract(sure_bg, sure_fg)
    
    # Create a marker image
    _, markers = cv2.connectedComponents(sure_fg)
    markers = markers + 1
    markers[unknown == 255] = 0
    
    # Apply the watershed algorithm
    markers = cv2.watershed(image, markers)
    
    # Color the segmented cells
    image[markers == -1] = [0, 0, 255]  # Mark boundaries with red color
    
    return image

# Provide the path to the folder containing the input images
folder_path = 'severe_dysplastic_filtered_nlm_aug'

# Get a list of all image files in the folder
image_files = [f for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))]

# Process each image in the folder
for image_file in image_files:
    # Construct the full path to the image
    image_path = os.path.join(folder_path, image_file)
    
    # Perform image segmentation
    segmented_image = segment_cell(image_path)
    
    # Save the segmented image with the same filename and BMP extension
    output_path = os.path.splitext(image_path)[0] + ".png"
    cv2.imwrite(output_path, segmented_image)
    
    print(f"Segmented image saved successfully as png: {output_path}")
# Out:
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153826963-153826970-001_filtered_0.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153826963-153826970-001_filtered_1.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153826963-153826970-001_filtered_2.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153826963-153826970-001_filtered_3.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153826963-153826970-001_filtered_4.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153826963-153826976-001_filtered_0.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153826963-153826976-001_filtered_1.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153826963-153826976-001_filtered_2.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153826963-153826976-001_filtered_3.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153826963-153826976-001_filtered_4.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153826963-153826976-002_filtered_0.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153826963-153826976-002_filtered_1.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153826963-153826976-002_filtered_2.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153826963-153826976-002_filtered_3.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153826963-153826976-002_filtered_4.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153826963-153826976-003_filtered_0.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153826963-153826976-003_filtered_1.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153826963-153826976-003_filtered_2.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153826963-153826976-003_filtered_3.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153826963-153826976-003_filtered_4.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153826963-153826982-001_filtered_0.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153826963-153826982-001_filtered_1.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153826963-153826982-001_filtered_2.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153826963-153826982-001_filtered_3.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153826963-153826982-001_filtered_4.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153826963-153826982-002_filtered_0.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153826963-153826982-002_filtered_1.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153826963-153826982-002_filtered_2.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153826963-153826982-002_filtered_3.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153826963-153826982-002_filtered_4.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153826963-153826982-003_filtered_0.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153826963-153826982-003_filtered_1.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153826963-153826982-003_filtered_2.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153826963-153826982-003_filtered_3.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153826963-153826982-003_filtered_4.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153826963-153826989-001_filtered_0.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153826963-153826989-001_filtered_1.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153826963-153826989-001_filtered_2.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153826963-153826989-001_filtered_3.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153826963-153826989-001_filtered_4.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153826963-153826989-002_filtered_0.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153826963-153826989-002_filtered_1.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153826963-153826989-002_filtered_2.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153826963-153826989-002_filtered_3.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153826963-153826989-002_filtered_4.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153827595-153827604-001_filtered_0.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153827595-153827604-001_filtered_1.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153827595-153827604-001_filtered_2.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153827595-153827604-001_filtered_3.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153827595-153827604-001_filtered_4.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153827595-153827604-002_filtered_0.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153827595-153827604-002_filtered_1.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153827595-153827604-002_filtered_2.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153827595-153827604-002_filtered_3.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153827595-153827604-002_filtered_4.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153827595-153827604-004_filtered_0.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153827595-153827604-004_filtered_1.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153827595-153827604-004_filtered_2.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153827595-153827604-004_filtered_3.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153827595-153827604-004_filtered_4.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153827595-153827611-001_filtered_0.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153827595-153827611-001_filtered_1.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153827595-153827611-001_filtered_2.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153827595-153827611-001_filtered_3.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153827595-153827611-001_filtered_4.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153827595-153827611-002_filtered_0.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153827595-153827611-002_filtered_1.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153827595-153827611-002_filtered_2.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153827595-153827611-002_filtered_3.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153827595-153827611-002_filtered_4.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153827595-153827618-001_filtered_0.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153827595-153827618-001_filtered_1.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153827595-153827618-001_filtered_2.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153827595-153827618-001_filtered_3.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153827595-153827618-001_filtered_4.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153827595-153827618-002_filtered_0.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153827595-153827618-002_filtered_1.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153827595-153827618-002_filtered_2.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153827595-153827618-002_filtered_3.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153827595-153827618-002_filtered_4.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153828877-153828890-001_filtered_0.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153828877-153828890-001_filtered_1.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153828877-153828890-001_filtered_2.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153828877-153828890-001_filtered_3.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153828877-153828890-001_filtered_4.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153828877-153828890-002_filtered_0.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153828877-153828890-002_filtered_1.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153828877-153828890-002_filtered_2.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153828877-153828890-002_filtered_3.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153828877-153828890-002_filtered_4.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153828877-153828897-001_filtered_0.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153828877-153828897-001_filtered_1.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153828877-153828897-001_filtered_2.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153828877-153828897-001_filtered_3.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153828877-153828897-001_filtered_4.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153828877-153828902-002_filtered_0.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153828877-153828902-002_filtered_1.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153828877-153828902-002_filtered_2.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153828877-153828902-002_filtered_3.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153828877-153828902-002_filtered_4.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153828952-153828970-001_filtered_0.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153828952-153828970-001_filtered_1.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153828952-153828970-001_filtered_2.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153828952-153828970-001_filtered_3.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153828952-153828970-001_filtered_4.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153828952-153828980-001_filtered_0.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153828952-153828980-001_filtered_1.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153828952-153828980-001_filtered_2.png
# Segmented image saved successfully as png: severe_dysplastic_filtered_nlm_aug\153828952-